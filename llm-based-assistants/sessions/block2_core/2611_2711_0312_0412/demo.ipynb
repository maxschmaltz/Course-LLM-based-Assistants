# %%
from website_generaion_lama import WebsiteGenerationLaMA

# %%
website_gen = WebsiteGenerationLaMA()
website_gen.run()
# I want a cool modern website about neon motorbikes
# Out:
# ================================ Human Message =================================
#
# I want a cool modern website about neon motorbikes
#
#
# ====================== Plan From Amily ======================
#
#
# {
#     "author": "Amily",
#     "items": [
#         {
#             "agent": "Amily",
#             "action_description": "Create a content plan for the neon motorbikes website, including the types of content to be featured, such as articles, images, and videos."
#         },
#         {
#             "agent": "Amily",
#             "action_description": "Research and write high-quality content for the website, including articles about neon motorbikes, their features, and benefits. Utilize the search engine tool to gather information and ensure accuracy."
#         },
#         {
#             "agent": "Kai",
# ...
